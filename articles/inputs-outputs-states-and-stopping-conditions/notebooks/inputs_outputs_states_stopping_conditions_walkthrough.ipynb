# %% [markdown]
# # Inputs, Outputs, States, and Stopping Conditions
#
# Notebook-ready placeholder for procedural boundaries, state transitions, stopping conditions, validation, invariants, failure reporting, and governance.

# %% [markdown]
# $$P = (I, O, S, T, C, H)$$
#
# $$A(I, s_0) \rightarrow (O, s_k)$$
#
# $$\exists k \geq 0 \text{ such that } H(s_k)=1$$
